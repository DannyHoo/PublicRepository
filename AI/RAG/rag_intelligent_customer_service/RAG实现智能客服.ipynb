# %% [markdown]
# # 1. 安装Python环境和依赖
#
# - Python版本：3.12
# - 安装依赖的库：uv pip install sentence-transformers chromadb google-genai ollama
#     - sentence_transformers：加载embedding和cross-encoder模型。sentence-transformers 是一个基于 Hugging Face Transformers 的 Python 库，专门用于将文本（尤其是句子或段落）转换为高质量的语义向量（embeddings）。这些向量可以用于衡量文本之间的语义相似度，在自然语言处理（NLP）任务中非常有用。
#     - chromadb：向量数据库
#     - google-genai：Google的AI SDK，调用Gemini模型（如gemini-2.5-flash）。旧版本的库为google-generativeai，2025年12月之后推荐google-genai。官方建议：https://ai.google.dev/gemini-api/docs/libraries?hl=zh-cn
#     - ollama：通过Ollama调用本地运行的大模型

# %% [markdown]
# # 2. 索引

# %% [markdown]
# ## 2.1 数据切片
# 对文档【跨时空便民服务站.md】的内容，按照段落的维度进行切片，一共切成100段内容

# %%
from typing import List

# 对单个文档按段落切片（非空行）
def split_doc_into_chunks(doc_file: str) -> List[str]:
    with open(doc_file, 'r', encoding='utf-8') as file:
        content = file.read()
    # 按换行分割，并过滤掉空白段落
    return [chunk.strip() for chunk in content.split("\n") if chunk.strip()]

# 处理多个文档，并合并所有段落
def split_multiple_docs_into_chunks(doc_files: List[str]) -> List[str]:
    all_chunks = []
    for doc_file in doc_files:
        print(f"正在处理文档: {doc_file}")
        chunks = split_doc_into_chunks(doc_file)
        all_chunks.extend(chunks)  # 合并到总列表
    return all_chunks

# 为所有文档分片，并保存到chunks变量中
doc_paths = [
    "./docs/TwinFun商贸有限公司双十一活动优惠政策.txt",
    "./docs/TwinFun双人游戏机旗舰XPro的使用说明.txt",
    "./docs/TwinFun双人游戏机旗舰XPro的保修政策.txt"
]
chunks = split_multiple_docs_into_chunks(doc_paths)

for i, chunk in enumerate(chunks):
    print(f"[{i+1}] {chunk}\n")
# Out:
# 正在处理文档: ./docs/TwinFun商贸有限公司双十一活动优惠政策.txt
# 正在处理文档: ./docs/TwinFun双人游戏机旗舰XPro的使用说明.txt
# 正在处理文档: ./docs/TwinFun双人游戏机旗舰XPro的保修政策.txt
# [1] 一年一度的双十一消费狂欢已然开启，TwinFun商贸有限公司秉持“感恩回馈，让利消费者”的核心理念，率先推出面向全体新客户的专属优惠政策：活动期间（2025年10月24日-2025年11月11日）首次注册成为TwinFun会员的消费者，无需满足任何消费门槛，可直接在会员中心领取一张价值50元的无门槛现金券，券有效期与活动周期一致，可用于平台内除定制家具、进口奢侈品外的所有品类消费，下单时直接抵扣。
#
# [2] 针对长期支持TwinFun的老客户，公司特别定制了体现专属权益的优惠政策：以2025年1月1日-2025年10月23日为统计周期，依托CRM系统分析客户消费数据，消费金额1万元及以上的高活跃客户，直接赠送“1000减300”“2000减700”“5000减2000”满减券各1张；消费金额3000元-9999元的潜力客户，赠送“500减100”满减券2张+15%复购补贴券（单笔最高补贴200元）；消费金额3000元以下的复苏客户，赠送“300减50”满减券3张，所有券种2025年11月1日-2025年11月11日可用。
#
# [3] 为简化购物流程，让消费者直观享受实惠，TwinFun推出“官方直降，一件也打折”的优惠政策：10月24日0点起，平台内1200款热门商品直接标注双十一折扣价，无需凑单、计算满减，其中冰箱、洗衣机这几类大家电全场5折，空调、热水器全场5.5折；潮流服饰、鞋帽箱包类商品直降30%，部分断码款式直降50%；美妆护肤类商品直降20%，且支持叠加品牌优惠券，折扣信息在商品详情页实时更新。
#
# [4] 聚焦家庭消费场景，TwinFun精心设计了“套餐组合更省钱”的优惠政策：针对家电、家居、母婴三大品类推出8款主题套餐，“厨房焕新套餐”包含指定品牌烟机（原价2999元）、灶具（原价1599元）、热水器（原价1899元），组合价4997元，比单独购买立省1500元；“亲子成长套餐”包含1-3岁儿童羽绒服2件、益智玩具3套、婴幼儿洗护用品4件，套餐价899元，较单品总价直降40%；所有套餐支持拆分发货，下单后48小时内安排出库。
#
# [5] 为激活线上线下全域消费活力，TwinFun推出“线上下单，线下畅享双重福利”的优惠政策：消费者通过TwinFun小程序或官方APP下单后，选择“门店自提”（全国32家线下门店通用），自提时可额外获赠定制马克杯1个；同时线下门店同步开展“体验有礼”活动，到店参与家电功能演示、服饰穿搭体验等互动，即可领取10元无门槛券（线上线下通用，有效期7天）；自提订单与体验礼品可同步领取，活动覆盖所有线下门店。
#
# [6] 借力社群社交属性，TwinFun推出“拼团裂变享低价”的优惠政策：活动期间，消费者在商品详情页点击“发起拼团”即可成为团长，生鲜食品、日用百货等200余款高频商品支持拼团，3人成团享8折，5人成团享6.8折，10人成团则团长可获得“实付金额全额返现”权益；拼团有效期为24小时，团长成功邀请好友参团后，系统自动发放对应折扣，返现金额在拼团完成后24小时内转入余额可直接提现。
#
# [7] 考虑到消费者的提前备货需求，TwinFun推出“预售定金膨胀”优惠政策：2025年10月24日0点-2025年11月10日22点，平台内高端家电、进口家具等150款商品支持预售，消费者支付定金即可享受膨胀权益，其中单价5000元以上商品定金“100抵500”，3000-5000元商品定金“50抵300”，1000-3000元商品定金“20抵100”；定金支付后，需在2025年11月11日0点-24点支付尾款，预售商品将在尾款支付完成后48小时内优先发货，定金不退但可抵作货款。
#
# [8] 深化异业合作资源，TwinFun联合多家银行、餐饮品牌推出“跨界联动补贴”优惠政策：活动期间，使用工商银行、建设银行信用卡支付，可享受“满1000减200”“满500减100”补贴（单卡各限1次）；使用招商银行信用卡支付，可享受3期免息分期+“满800减150”补贴；同时，购买TwinFun商品实付满500元，订单完成后将自动发放肯德基50元无门槛代金券1张，代金券有效期至12月31日，全国门店通用。
#
# [9] 为回馈会员的长期支持，TwinFun推出“会员积分翻倍+专属兑换”优惠政策：2025年11月1日-2025年11月11日，所有TwinFun会员消费均可享受2倍积分累积（1元=2积分），积分无有效期限制；积分可直接在“积分商城”兑换商品，1000积分可兑换50元现金券，5000积分可兑换品牌蓝牙耳机（价值399元）；每日10点、15点，会员专属通道开放“积分秒杀”，500积分可秒杀100元满减券（满200可用），每场限量100份，先到先得。
#
# [10] 关注消费者的售后保障需求，TwinFun推出“购物无忧保障”优惠政策：活动期间购买的商品，均享受“30天无理由退换货”服务（食品、贴身衣物等特殊品类除外），且退换货运费由平台承担；冰箱、洗衣机等大家电享受免费上门安装服务，同时在原有保修基础上增加1年延保；所有活动期间下单的消费者，确认收货后可在订单页参与“订单抽奖”，一等奖1名（价值3000元的家庭影音设备），二等奖10名（价值500元的家电优惠券），三等奖100名（定制周边大礼包），开奖时间为2025年11月15日。
#
# [11] 开箱与部件识别：TwinFun XPro标配含1台主机、2个无线手柄、1个双人摇杆控台、1根HDMI 2.1高清线、1根主机电源线、1根摇杆控台Type-C充电线及1份快速指南。主机正面为电源键（带指示灯）和USB 3.0接口，背面依次分布HDMI输出口、电源接口、网线接口及复位键；摇杆控台顶部设1P/2P操作键、暂停键，底部有6个防滑吸盘，手柄则配备方向键、动作键（A/B/X/Y）及配对键。
#
# [12] 主机基础连接：首先将主机放置在通风良好处（避免遮挡顶部散热孔），将电源线一端插入主机背面电源接口，另一端接入220V交流插座。接着取HDMI线，一端插入主机HDMI输出口，另一端连接电视/显示器的HDMI输入接口（建议标注为HDMI 1）。连接完成后，打开主机电源键（指示灯呈蓝色常亮为开机成功），随后开启电视/显示器，通过遥控器切换信号源至对应HDMI接口，即可显示游戏机主界面。若出现画面延迟，可在电视设置中开启“游戏模式”。
#
# [13] 手柄与摇杆配对：无线手柄配对需先取出手柄背部接收器，插入主机正面USB 3.0接口，然后打开手柄电源开关（位于手柄顶部），当手柄指示灯呈绿色常亮时，代表配对成功（1P手柄对应1个指示灯，2P对应2个指示灯），单个接收器可同时连接2个手柄，手柄需自备2节7号电池（建议使用碱性电池，避免混用新旧电池或不同品牌电池）。若出现手柄连不上的问题，可按以下步骤排查：1. 确认接收器已完全插入USB接口，可拔插后重试；2. 检查电池安装是否正确（正负极是否对应），更换新电池测试；3. 按住手柄配对键3秒重置手柄，再重新开启配对；4. 若仍失败，尝试更换主机其他USB接口或重启主机。双人摇杆控台为即插即用设计，将其Type-C充电线接入主机USB接口或5V/2A规格充电器，按下摇杆控台电源键（红色按钮），指示灯闪烁后变为常亮，即完成与主机的自动配对，低电量时指示灯呈红色闪烁。
#
# [14] 开机与系统初始化：首次开机时，系统会引导完成基础设置，依次选择语言（支持中文、英文等8种语言）、时区（默认自动获取，可手动调整），随后进入网络设置界面。网络连接支持有线和无线两种方式：有线连接需插入网线即可自动联网；无线连接需选择对应WiFi信号，输入密码（支持2.4G/5G双频段），连接成功后系统会自动检测更新，首次更新约需3-5分钟（更新期间不可断电），完成后进入游戏主界面。
#
# [15] 游戏库浏览与启动：主界面分为“游戏分类”“最近游玩”“收藏夹”三个板块，通过手柄方向键或摇杆控台方向杆可切换选项，按A键确认选择。“游戏分类”涵盖格斗、闯关、竞速等8大类，每类游戏均标注支持人数及操作方式；若需快速查找游戏，可按手柄X键进入搜索界面，通过方向键输入游戏名称首字母（B键为回退键），确认后即可直达目标游戏。选中游戏后点击“开始游戏”，系统会提示1P/2P玩家准备，待双方按下各自设备的确认键后，即可进入游戏。
#
# [16] 双人模式设置与操作：本地双人游戏时，1P默认使用摇杆控台或左侧手柄，2P使用右侧手柄，系统会自动分配玩家标识（屏幕角落显示1P/2P图标）。若需调整设备分配，可在主界面按手柄SELECT键进入“设备设置”，选择“玩家配置”，将1P/2P分别绑定至目标设备（支持摇杆与手柄混合使用），设置后需按A键保存。游戏过程中，1P/2P可通过各自设备的暂停键暂停游戏，暂停界面提供“继续游戏”“存储进度”“读取进度”“退出游戏”四个选项，按A键确认对应操作。
#
# [17] 按键自定义与连发设置：针对不同游戏操作需求，可自定义按键功能。在主界面进入“系统设置-按键配置”，选择对应设备（摇杆/手柄）及玩家，按提示按住需自定义的按键，再按下目标按键即可完成修改（如将摇杆的“跳跃键”从A键改为B键），修改后可选择“保存方案”或“恢复默认”。连发功能需在游戏中启用，1P玩家同时按住摇杆控台的1P键与目标动作键（如A键），此时按键指示灯闪烁，代表连发功能开启（按住按键即可持续触发动作）；关闭时再次同时按下这两个键即可，手柄连发设置操作相同（按手柄SELECT键+目标动作键）。
#
# [18] 画面与音效调节：画面参数可在“系统设置-显示设置”中调整，支持480P/720P/1080P/4K四种分辨率（需电视/显示器支持对应分辨率及HDMI 2.1协议，若电视仅支持HDMI 1.4，最高仅能输出1080P分辨率）。提高游戏帧率和分辨率的操作方法如下：1. 分辨率设置：进入“显示设置”后，根据显示设备参数选择最高支持分辨率（如4K电视可直接勾选4K选项），勾选后系统会自动保存；2. 帧率优化：在“显示设置”中开启“性能模式”，该模式会优先保障帧率稳定（最高可达60Hz），同时关闭画面边缘抗锯齿等非必要特效；3. 设备适配：若开启高分辨率后帧率下降，可适当降低分辨率至1080P，或在游戏内设置中单独调低画面细节（如纹理质量、粒子效果）。刷新率默认为60Hz，开启“高清模式”后可提升画面细节，但部分老款设备可能出现卡顿。音效调节分为主机音量和游戏内音量，主机侧面设物理音量调节滚轮，顺时针增大、逆时针减小；游戏内音量需在对应游戏的设置界面调整，部分游戏支持“立体声音效”开关，适合搭配外接音箱使用。
#
# [19] 系统更新与维护：在线更新可在“系统设置-系统更新”中手动触发，系统会自动检测最新固件，更新包大小约500MB-1GB，建议在WiFi稳定环境下进行，更新过程中主机将自动重启。若在线更新失败，可采用USB手动更新：在电脑上登录TwinFun官网下载最新固件，将其保存至FAT32格式的USB硬盘（需新建“XPro”文件夹，子文件夹命名“UPDATE”，固件文件重命名为“XPROUPDATE.PUP”），将USB插入主机USB接口，按住主机背面复位键的同时开机，待指示灯呈橙色闪烁时松开，选择“USB更新”即可。日常维护需每月用压缩空气清理主机散热孔灰尘，避免积尘导致过热。
#
# [20] 常见故障排查与安全须知：若主机无法开机，先检查电源线连接及插座供电，更换电源线重试；若开机后无显示，确认HDMI线插紧，尝试更换HDMI接口或线缆。手柄断连时，重新插拔接收器并重启手柄；摇杆无响应则检查充电状态，确保电量充足。针对“电池充不进电”问题，需先区分设备类型：1. 无线手柄为干电池供电，无充电功能，若误将普通干电池接入充电设备，可能导致电池漏液损坏手柄；2. 摇杆控台若充不进电，排查步骤为：确认使用原装Type-C充电线，检查充电线是否破损；更换5V/2A规格充电器（避免使用快充头）；检查摇杆控台充电接口是否有灰尘堵塞，用干棉签清理后重试。安全方面，主机需使用原装电源线，避免在潮湿、高温环境使用；游戏连续运行超过4小时需关机休息30分钟，防止过热；儿童使用时需在成人监护下进行，避免误吞手柄电池或触碰电源接口，清洁设备需用干布擦拭，禁止用水直接冲洗。
#
# [21] 保修范围与期限界定：本保修政策仅适用于通过TwinFun品牌官方商城、线下授权门店及天猫、京东官方旗舰店购买的XPro正品设备，非授权渠道购买的设备不享受官方保修服务。核心部件保修期限差异明确：主机（含主板、芯片、散热模块）享受自购买日起2年免费保修；无线手柄、双人摇杆控台等标配功能性配件保修1年；HDMI线、电源线、充电线等易损耗附件保修期限为3个月。保修起始日期以购机发票开具日期为准，无发票时则以设备首次激活日期或电商平台订单生成日期中最早者计算，且仅在中国内地（不含港澳台）区域有效。
#
# [22] 保修申请凭证与流程：申请免费保修需提供三项核心凭证，缺一不可，分别为：1. 清晰完整的购机发票（需标注设备型号、机身序列号、购买日期及金额）；2. 设备原装保修卡（需填写完整个人信息及销售方公章）；3. 主机底部的机身序列号（不可涂改或撕毁）。若凭证丢失，需通过购买账号登录官方客服中心，上传订单截图、设备激活记录及机身序列号照片，经审核确认设备归属及购买信息后，方可启动保修流程。申请前需自行备份设备内游戏存档及个人数据，官方维修过程中若需格式化设备，不承担数据恢复责任。
#
# [23] 免费保修免责情形：以下故障或损坏不属于免费保修范畴，需付费维修：因人为操作不当导致的损坏，如主机摔落造成的外壳开裂、摇杆控台按键按压过度失灵；未按使用说明操作引发的故障，包括使用非原装充电器给摇杆控台充电导致的电路烧毁、自行拆卸主机改装硬件；自然损耗及外观磨损，如手柄键帽褪色、主机外壳划痕、电池电量自然衰减；不可抗力因素导致的损坏，如洪水浸泡、雷击、火灾等；机身序列号模糊、篡改或移除的设备，以及过保后出现的任何故障。
#
# [24] 维修服务保障与规范：设备经审核符合保修条件后，采取“双向免邮”服务模式，用户寄回故障设备的运费由品牌方承担（需选择顺丰快递到付），维修完成后寄回的运费同样由官方承担。维修周期通常为5-7个工作日，若需更换核心部件（如主机主板），客服会提前通过短信或电话与用户确认部件信息及维修时长，征得同意后方可操作。维修后的设备将享受“双重保障”：若原保修未到期，延续剩余保修时间；若原保修已到期，自维修完成日起额外提供90天保修服务，维修记录可在官方客服中心查询。
#
# [25] 延保服务与增值保障：为延长设备保障周期，用户可在原保修到期前30天内，通过官方APP或客服热线购买延保服务。延保费用明确定价：主机单独延保1年费用199元，延保2年费用349元；全套设备（主机+所有标配配件）延保1年费用299元，延保2年费用549元。延保服务与原保修范围一致，购买后即时生效并与原保修无缝衔接。此外，可额外购买“意外保障服务”，399元/年，覆盖人为摔落、液体泼溅、意外挤压等非人为故障，购买后需在48小时内完成设备外观及功能验机备案，未备案则保障无效。

# %% [markdown]
# ## 2.2 把文档的所有的分片都转化为向量

# %%
from sentence_transformers import SentenceTransformer

# 创建一个embedding模型，首次加载速度可能较慢，需要从Hugging Face上拉取模型
embedding_model= SentenceTransformer("shibing624/text2vec-base-chinese")

# 定义一个方法embed_chunk，用于将某一段文本转化为对应的多维向量，返回这段文字所对应的多维向量的数组
def embed_chunk(chunk: str) -> List[float]:
    embedding = embedding_model.encode(chunk)
    return embedding;

#   6.69510484e-01  7.35013634e-02  2.86524892e-01  8.08336120e-03
#  -4.52505648e-01 -2.53353179e-01  7.22350597e-01 -3.73378575e-01
#  -2.77892560e-01 -3.69801104e-01 -5.33790946e-01  1.42608210e-01]

# %% [markdown]
# ## 2.3 把文本和对应的向量存入向量数据库

# %%
import chromadb

# 创建一个文件型的数据库
chromadb_client=chromadb.PersistentClient("./db/chroma.db")
# chromadb表
chromadb_collection = chromadb_client.get_or_create_collection(name="default")

# 把文本及对应的向量保存到向量数据库（也可以用collection的upsert方法按照id更新）
def save_embeddings(chunks:List[str], embeddings:List[List[float]]) -> None:
    ids = [str(i) for i in range(len(chunks))]
    chromadb_collection.add(
        documents=chunks,
        embeddings=embeddings,
        ids=ids
    )

# 保存文本数组及对应的向量数组
save_embeddings(chunks,embeddings)

# %% [markdown]
# # 3. 检索

# %%
# 定义一个方法，用于检索指定文本在向量数据库中语义相近的前k个片段
def retrieve(query:str,top_k:int) -> List[str]:
    # 把查询文本（也就是用户提问的问题）转化为检索向量
    query_embeding=embed_chunk(query)
    # 根据检索向量在数据库中查询语义相近的前k个片段
    results = chromadb_collection.query(
        query_embeddings=[query_embeding],
        n_results=top_k
    )
    return results['documents'][0]

#question="TwinFun XPro手柄链接不上是什么原因？"
question="哪些渠道购买的TwinFun XPro可享受官方保修？主机和无线手柄的免费保修期限分别是多久？"
retrieve_chunks=retrieve(question,5)

print(f"从向量数据库中查询到的与问题【{question}】语义相近的前n个匹配的结果：\n")
for i, result in enumerate(retrieve_chunks):
    print(f"{i+1}. {result}\n")
# Out:
# 从向量数据库中查询到的与问题【哪些渠道购买的TwinFun XPro可享受官方保修？主机和无线手柄的免费保修期限分别是多久？】语义相近的前n个匹配的结果：
#
# 1. 保修范围与期限界定：本保修政策仅适用于通过TwinFun品牌官方商城、线下授权门店及天猫、京东官方旗舰店购买的XPro正品设备，非授权渠道购买的设备不享受官方保修服务。核心部件保修期限差异明确：主机（含主板、芯片、散热模块）享受自购买日起2年免费保修；无线手柄、双人摇杆控台等标配功能性配件保修1年；HDMI线、电源线、充电线等易损耗附件保修期限为3个月。保修起始日期以购机发票开具日期为准，无发票时则以设备首次激活日期或电商平台订单生成日期中最早者计算，且仅在中国内地（不含港澳台）区域有效。
#
# 2. 维修服务保障与规范：设备经审核符合保修条件后，采取“双向免邮”服务模式，用户寄回故障设备的运费由品牌方承担（需选择顺丰快递到付），维修完成后寄回的运费同样由官方承担。维修周期通常为5-7个工作日，若需更换核心部件（如主机主板），客服会提前通过短信或电话与用户确认部件信息及维修时长，征得同意后方可操作。维修后的设备将享受“双重保障”：若原保修未到期，延续剩余保修时间；若原保修已到期，自维修完成日起额外提供90天保修服务，维修记录可在官方客服中心查询。
#
# 3. 系统更新与维护：在线更新可在“系统设置-系统更新”中手动触发，系统会自动检测最新固件，更新包大小约500MB-1GB，建议在WiFi稳定环境下进行，更新过程中主机将自动重启。若在线更新失败，可采用USB手动更新：在电脑上登录TwinFun官网下载最新固件，将其保存至FAT32格式的USB硬盘（需新建“XPro”文件夹，子文件夹命名“UPDATE”，固件文件重命名为“XPROUPDATE.PUP”），将USB插入主机USB接口，按住主机背面复位键的同时开机，待指示灯呈橙色闪烁时松开，选择“USB更新”即可。日常维护需每月用压缩空气清理主机散热孔灰尘，避免积尘导致过热。
#
# 4. 延保服务与增值保障：为延长设备保障周期，用户可在原保修到期前30天内，通过官方APP或客服热线购买延保服务。延保费用明确定价：主机单独延保1年费用199元，延保2年费用349元；全套设备（主机+所有标配配件）延保1年费用299元，延保2年费用549元。延保服务与原保修范围一致，购买后即时生效并与原保修无缝衔接。此外，可额外购买“意外保障服务”，399元/年，覆盖人为摔落、液体泼溅、意外挤压等非人为故障，购买后需在48小时内完成设备外观及功能验机备案，未备案则保障无效。
#
# 5. 开箱与部件识别：TwinFun XPro标配含1台主机、2个无线手柄、1个双人摇杆控台、1根HDMI 2.1高清线、1根主机电源线、1根摇杆控台Type-C充电线及1份快速指南。主机正面为电源键（带指示灯）和USB 3.0接口，背面依次分布HDMI输出口、电源接口、网线接口及复位键；摇杆控台顶部设1P/2P操作键、暂停键，底部有6个防滑吸盘，手柄则配备方向键、动作键（A/B/X/Y）及配对键。

# %% [markdown]
# # 4. 重排（增强）

# %%
from sentence_transformers import CrossEncoder

# 定义一个排序方法，通过cross-encoder模型，对用户问题和多个片段之间的相似度打分、排序
def rerank(query:str, retrieve_chunks: List[str], top_k:int) -> List[str]:
    # 创建cross_encoder模型
    cross_encoder=CrossEncoder('cross-encoder/mmarco-mMiniLMv2-L12-H384-v1')
    # 用户问题+相似片段 列表
    pairs=[(query,chunk) for chunk in retrieve_chunks]
    # 用户问题和每个相似片段的重排分数
    scores=cross_encoder.predict(pairs)

    # 用户问题+每个相似片段 重排分数的列表
    chunk_with_score_list=[
        (chunk,score) for chunk,score in zip(retrieve_chunks,scores)
    ]
    # 按照分数倒序排序
    chunk_with_score_list.sort(key=lambda pair:pair[1],reverse=True)
    # 取top k
    return [chunk for chunk,_ in chunk_with_score_list][:top_k]

reranked_chunks=rerank(question,retrieve_chunks,3)

print(f"对匹配结果增强重排后，与问题【{question}】语义相近的前n个匹配的结果：\n")

for i,chunk in enumerate(reranked_chunks):
    print(f"{i+1}. {chunk}\n")
# Out:
# 对匹配结果增强重排后，与问题【哪些渠道购买的TwinFun XPro可享受官方保修？主机和无线手柄的免费保修期限分别是多久？】语义相近的前n个匹配的结果：
#
# 1. 保修范围与期限界定：本保修政策仅适用于通过TwinFun品牌官方商城、线下授权门店及天猫、京东官方旗舰店购买的XPro正品设备，非授权渠道购买的设备不享受官方保修服务。核心部件保修期限差异明确：主机（含主板、芯片、散热模块）享受自购买日起2年免费保修；无线手柄、双人摇杆控台等标配功能性配件保修1年；HDMI线、电源线、充电线等易损耗附件保修期限为3个月。保修起始日期以购机发票开具日期为准，无发票时则以设备首次激活日期或电商平台订单生成日期中最早者计算，且仅在中国内地（不含港澳台）区域有效。
#
# 2. 延保服务与增值保障：为延长设备保障周期，用户可在原保修到期前30天内，通过官方APP或客服热线购买延保服务。延保费用明确定价：主机单独延保1年费用199元，延保2年费用349元；全套设备（主机+所有标配配件）延保1年费用299元，延保2年费用549元。延保服务与原保修范围一致，购买后即时生效并与原保修无缝衔接。此外，可额外购买“意外保障服务”，399元/年，覆盖人为摔落、液体泼溅、意外挤压等非人为故障，购买后需在48小时内完成设备外观及功能验机备案，未备案则保障无效。
#
# 3. 维修服务保障与规范：设备经审核符合保修条件后，采取“双向免邮”服务模式，用户寄回故障设备的运费由品牌方承担（需选择顺丰快递到付），维修完成后寄回的运费同样由官方承担。维修周期通常为5-7个工作日，若需更换核心部件（如主机主板），客服会提前通过短信或电话与用户确认部件信息及维修时长，征得同意后方可操作。维修后的设备将享受“双重保障”：若原保修未到期，延续剩余保修时间；若原保修已到期，自维修完成日起额外提供90天保修服务，维修记录可在官方客服中心查询。

# %% [markdown]
# # 5. 生成
#
# 生成阶段，我们可以依赖不同的大语言模型进行生成。如果需要集成多个不同的大模型，可以使用OneAPI等聚合API来实现。
#
# 下面我们用两种方式来举例说明：通过Ollama调用本地大语言模型（通过Ollama等方式在本地部署大语言模型如Llama、DeepSeek等）、通过SDK调用三方大语言模型（Gemini、ChatGPT等）。

# %%
# 通过Ollama的SDK调用本地大模型生成结果
# 本地要先通过Ollama运行大模型

import ollama

def generate(query:str,chunks:List[str] )->str:
    prompt = f"""你是一位知识助手，请根据用户的问题和参考资料生成准确的回答。

用户问题: {query}

参考资料:
{"\n\n".join(chunks)}

请严格基于上述内容作答，不要编造信息，如果资料中没有答案，请回答“文档中未找到相关信息”。"""

    print(f"{prompt}\n\n---\n")
    
    try:
        response = ollama.chat(
            model='deepseek-r1:1.5b',
            messages=[{'role': 'user', 'content': prompt}],
        )
        return response['message']['content']
    except Exception as e:
        print(f"API调用失败: {e}")
        return "API调用失败";

# 生成测试
answer = generate(question,reranked_chunks);
print(answer)
# Out:
# 你是一位知识助手，请根据用户的问题和参考资料生成准确的回答。
#
# 用户问题: 哪些渠道购买的TwinFun XPro可享受官方保修？主机和无线手柄的免费保修期限分别是多久？
#
# 参考资料:
# 保修范围与期限界定：本保修政策仅适用于通过TwinFun品牌官方商城、线下授权门店及天猫、京东官方旗舰店购买的XPro正品设备，非授权渠道购买的设备不享受官方保修服务。核心部件保修期限差异明确：主机（含主板、芯片、散热模块）享受自购买日起2年免费保修；无线手柄、双人摇杆控台等标配功能性配件保修1年；HDMI线、电源线、充电线等易损耗附件保修期限为3个月。保修起始日期以购机发票开具日期为准，无发票时则以设备首次激活日期或电商平台订单生成日期中最早者计算，且仅在中国内地（不含港澳台）区域有效。
#
# 延保服务与增值保障：为延长设备保障周期，用户可在原保修到期前30天内，通过官方APP或客服热线购买延保服务。延保费用明确定价：主机单独延保1年费用199元，延保2年费用349元；全套设备（主机+所有标配配件）延保1年费用299元，延保2年费用549元。延保服务与原保修范围一致，购买后即时生效并与原保修无缝衔接。此外，可额外购买“意外保障服务”，399元/年，覆盖人为摔落、液体泼溅、意外挤压等非人为故障，购买后需在48小时内完成设备外观及功能验机备案，未备案则保障无效。
#
# 维修服务保障与规范：设备经审核符合保修条件后，采取“双向免邮”服务模式，用户寄回故障设备的运费由品牌方承担（需选择顺丰快递到付），维修完成后寄回的运费同样由官方承担。维修周期通常为5-7个工作日，若需更换核心部件（如主机主板），客服会提前通过短信或电话与用户确认部件信息及维修时长，征得同意后方可操作。维修后的设备将享受“双重保障”：若原保修未到期，延续剩余保修时间；若原保修已到期，自维修完成日起额外提供90天保修服务，维修记录可在官方客服中心查询。
#
# 请严格基于上述内容作答，不要编造信息，如果资料中没有答案，请回答“文档中未找到相关信息”。
#
# ---
#
# <think>
# 好，我现在需要处理用户的查询。用户问的是TwinFun XPro可以享受官方保修的渠道有哪些，以及主机和无线手柄的免费保修期限分别是多久。首先，我要仔细阅读参考资料，确保理解所有信息。
#
# 根据参考资料，Prime会员购买的设备是免修的，而且不享受保修服务。而线下授权门店、天猫、京东官方旗舰店等渠道的用户可以享受保修。这里需要注意的是，不同地区可能有区别的保修起始日期和免费期限。
#
# 对于主机部分，包括主板、芯片、散热模块，免费保修期限是从购买之日起2年。无线手柄、双人摇杆控台等标配配件保修1年。HDMI线、电源线、充电线等易损耗附件保修3个月。这些信息要详细列出，并说明地区限制。
#
# 延保服务部分提到，用户可以在原保修期前30天内购买延保服务，费用根据设备类型不同。例如，主机单独延保1年199元，双人版本更贵299元。此外，可以额外购买意外保障，价格更高，需要在48小时内完成验机备案。
#
# 维修服务方面，用户需提供运费支付，设备在维修后需通过官方客服查询记录，并享受双重保修。这需要提到如果原保修未满期，可延续剩余时间；如果已满期，则有额外90天保修。
#
# 我还需要确保回答准确无误，没有编造信息。如果有资料中没有的信息，就用“文档中未找到相关信息”来表示。用户可能是在购买设备后希望延长保障周期，所以延保和维修服务部分也很重要。
#
# 最后，组织语言时要清晰明了，分点列出不同方面，比如渠道、保修期限、延保费用等，这样用户能一目了然地理解信息。
# </think>
#
# 根据参考资料，TwinFun XPro的产品可以享受官方保修的渠道如下：
#
# 1. **渠道购买**：Prime会员和线下授权门店、天猫、京东官方旗舰店等线下品牌门店均可享受官方保修服务。
#
# 2. **核心部件（主机）**：
#    - 主机（含主板、芯片、散热模块）免费保修，期限为从购买之日起2年。
#
# 3. **标配功能性配件**：
#    - 线上机的无线手柄、双人摇杆控台等标配功能配件免费保修，期限为1年。
#    - 配件如HDMI线、电源线、充电线等易耗附件免费保修，周期为3个月。
#
# 4. **地区范围**：保修起始日期由购机发票开具日期为准，无发票时则以设备首次激活日期或电商平台订单生成日期中最早者计算。仅在中国内地（不含港澳台）有效。
#
# **延保服务与增值保障**：
# - 延保费用明确定价：主机单独延保1年费用199元，延保2年费用349元；全套设备（主机+标配配件）延保1年费用299元，延保2年费用549元。
# - 延保服务与原保修范围一致，购买后即时生效并与原保修无缝衔接。
# - 可额外购买“意外保障服务”，价格为399元/年，覆盖人为摔落、液体泼溅等非人为故障。购买后需在48小时内完成设备外观及功能验机备案，若未完成，则保障无效。
#
# **维修服务保障与规范**：
# - 设备经审核符合保修条件后，采取“双向免邮”服务模式。
# - 用户寄回故障设备的运费由品牌方承担（需选择顺丰快递到付）。
# - 维修完成后寄回的运费同样由官方承担。
# - 维修周期通常为5-7个工作日。如果需要更换核心部件（如主机），客服会提前通过短信或电话与用户确认部件信息及维修时长，并征得同意后方可操作。
#
# 总结来说，Prime会员和线下授权门店等渠道购买设备可享受官方保修服务，而在线上官方旗舰店的TwinFun XPro产品则有对应的保修条款。

# %%
# 调用大语言模型生成结果
# 调用Google的Gemini，依赖google-genai
# 运行需要通过设置国外节点VPN（建议热点）
from google import genai
client = genai.Client(api_key="AIzaSyD-l1J5qt0VhDOmLASJPxaG_7If5BXvm8Q")

def generate(query:str,chunks:List[str] )->str:
    prompt = f"""你是一位知识助手，请根据用户的问题和参考资料生成准确的回答。

用户问题: {query}

参考资料:
{"\n\n".join(chunks)}

请严格基于上述内容作答，不要编造信息，如果资料中没有答案，请回答“文档中未找到相关信息”。"""

    print(f"{prompt}\n\n---\n")
    
    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt,
        )
        return response.text
    except Exception as e:
        print(f"API调用失败: {e}")
        return "API调用失败";

# 生成测试
answer = generate(question,reranked_chunks);
print(answer)
# Out:
# 你是一位知识助手，请根据用户的问题和参考资料生成准确的回答。
#
# 用户问题: 哪些渠道购买的TwinFun XPro可享受官方保修？主机和无线手柄的免费保修期限分别是多久？
#
# 参考资料:
# 保修范围与期限界定：本保修政策仅适用于通过TwinFun品牌官方商城、线下授权门店及天猫、京东官方旗舰店购买的XPro正品设备，非授权渠道购买的设备不享受官方保修服务。核心部件保修期限差异明确：主机（含主板、芯片、散热模块）享受自购买日起2年免费保修；无线手柄、双人摇杆控台等标配功能性配件保修1年；HDMI线、电源线、充电线等易损耗附件保修期限为3个月。保修起始日期以购机发票开具日期为准，无发票时则以设备首次激活日期或电商平台订单生成日期中最早者计算，且仅在中国内地（不含港澳台）区域有效。
#
# 延保服务与增值保障：为延长设备保障周期，用户可在原保修到期前30天内，通过官方APP或客服热线购买延保服务。延保费用明确定价：主机单独延保1年费用199元，延保2年费用349元；全套设备（主机+所有标配配件）延保1年费用299元，延保2年费用549元。延保服务与原保修范围一致，购买后即时生效并与原保修无缝衔接。此外，可额外购买“意外保障服务”，399元/年，覆盖人为摔落、液体泼溅、意外挤压等非人为故障，购买后需在48小时内完成设备外观及功能验机备案，未备案则保障无效。
#
# 维修服务保障与规范：设备经审核符合保修条件后，采取“双向免邮”服务模式，用户寄回故障设备的运费由品牌方承担（需选择顺丰快递到付），维修完成后寄回的运费同样由官方承担。维修周期通常为5-7个工作日，若需更换核心部件（如主机主板），客服会提前通过短信或电话与用户确认部件信息及维修时长，征得同意后方可操作。维修后的设备将享受“双重保障”：若原保修未到期，延续剩余保修时间；若原保修已到期，自维修完成日起额外提供90天保修服务，维修记录可在官方客服中心查询。
#
# 请严格基于上述内容作答，不要编造信息，如果资料中没有答案，请回答“文档中未找到相关信息”。
#
# ---
#
# TwinFun XPro可通过以下渠道购买并享受官方保修：TwinFun品牌官方商城、线下授权门店、天猫官方旗舰店及京东官方旗舰店。
#
# 关于免费保修期限：
# *   主机（含主板、芯片、散热模块）享受自购买日起2年免费保修。
# *   无线手柄享受1年免费保修。
